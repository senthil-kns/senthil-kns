# %% [markdown]
# <a href="https://colab.research.google.com/github/senthil-kns/senthil-kns/blob/main/Assignment_Pandas_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
x = 'https://raw.githubusercontent.com/balaji2v/Inceptez_Batch19/main/Demand_txn_updated.csv'
df = pd.read_csv(x)
print(df)
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
xx = 'https://raw.githubusercontent.com/balaji2v/Inceptez_Batch19/main/company.csv'
ddff = pd.read_csv(xx)
print(ddff)
# Out:
#      Company   Age  Salary     Place Country
# 0        TCS  20.0     NaN   Chennai   India
# 1    Infosys  30.0     NaN    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN     NaN       NaN     NaN
#
# [149 rows x 5 columns]

# %%
# dataframe dimension
df.shape
# Out:
# (30231, 22)

# %%
# List down all the columns in data frame
df.head(0)
# Out:
# Empty DataFrame
# Columns: [City, Mapped_Sales_Type, Mapped_Item_Code, Transaction_Date, Quantity_Sold, Median_Price, Average_Tax_Percent, Effective_Price, Percent_Quantity_With_Discount, Avg_Discount_Percent_On_Discounted_Items, Year, Month, Day, Car_sales, F_and_B_Inflation, F_and_B_Inflation_Adjusted_Effective_Price, F_and_B_Inflation_Adjusted_Median_Price, First_Week_Of_The_Month_Dummy, Last_Week_Of_The_Month_Dummy, Day_Of_The_Week_Seasonality, Month_Of_The_Year_Seasonality, Two_Wheeler_sales]
# Index: []
#
# [0 rows x 22 columns]

# %%
# List down all the columns in data frame

ddff.columns.values.tolist()
# Out:
# ['Company', 'Age', 'Salary', 'Place', 'Country']

# %%
# List the top 10 rows in datframe
df.head(10)
# Out:
#         City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0  Hyderabad         Take Away              9978        7/31/2018
# 1  Hyderabad         Take Away              4064        7/31/2018
# 2  Hyderabad         Main Hall               965        7/31/2018
# 3  Hyderabad           Express              9978        7/31/2018
# 4  Hyderabad           Express              1045        7/31/2018
# 5  Hyderabad          Delivery              4056        7/31/2018
# 6  Hyderabad         Take Away              4065        7/31/2018
# 7  Hyderabad           Express              4058        7/31/2018
# 8  Hyderabad           Express              4057        7/31/2018
# 9  Hyderabad           Express              4056        7/31/2018
#
#    Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 0            167         187.0                 0.05       163.700000
# 1            368         602.0                 0.05       584.329105
# ...

# %%
# List the last 15 rows in datframe
df.tail(15)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 30216  Mumbai         Take Away              4065         8/1/2016
# 30217  Mumbai         Take Away              4059         8/1/2016
# 30218  Mumbai          Delivery              4056         8/1/2016
# 30219  Mumbai          Delivery              4059         8/1/2016
# 30220  Mumbai         Take Away              4068         8/1/2016
# 30221  Mumbai          Delivery              4066         8/1/2016
# 30222  Mumbai         Main Hall               970         8/1/2016
# 30223  Mumbai         Main Hall               971         8/1/2016
# 30224  Mumbai          Delivery              4062         8/1/2016
# 30225  Mumbai         Take Away              4063         8/1/2016
# 30226  Mumbai         Take Away              4056         8/1/2016
# 30227  Mumbai         Take Away              4058         8/1/2016
# 30228  Mumbai           Dine-in               964         8/1/2016
# ...

# %%
# Find the number of rows in dataframe
print(pd.options.display.max_rows)
# Out:
# 60

# %%
# Find the number of rows in dataframe
rows =len(df.index)
print("No.of Rows ="+str(rows))
# Out:
# No.of Rows =30231

# %%
print("No.of Rows =", len(df))
# Out:
# No.of Rows = 30231

# %%
# to find no.of rows 
print("No.Of rows =",df.shape[0])
# Out:
# No.Of rows = 30231

# %%
# to find the no.Column
print(df.shape[1])
# Out:
# 22

# %%
# Check the information of dataframe

x=df.info()
print(x)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30231 entries, 0 to 30230
# Data columns (total 22 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   City                                        30231 non-null  object
#  1   Mapped_Sales_Type                           30231 non-null  object
#  2   Mapped_Item_Code                            30231 non-null  int64
#  3   Transaction_Date                            30231 non-null  object
#  4   Quantity_Sold                               30231 non-null  int64
#  5   Median_Price                                30231 non-null  float64
#  6   Average_Tax_Percent                         30231 non-null  float64
#  7   Effective_Price                             30229 non-null  float64
#  8   Percent_Quantity_With_Discount              12209 non-null  float64
# ...

# %%
# Check the basic Statistics of Dataframe. Give your inference from the stats
Basic_stats = ddff.agg({"Age":["min","max","median","skew"],"Salary":["min","max","median","skew"]})
print(Basic_stats)
# Out:
#               Age       Salary
# min      0.000000  1089.000000
# max     54.000000  9876.000000
# median  32.500000  5000.000000
# skew    -0.583808     0.169639

# %%
# Retrieve 20 to 100 rows and Company and age usig iloc
x = ddff.iloc[20:100,:2]
print(x)
# Out:
#     Company   Age
# 20      TCS  37.0
# 21  Infosys  50.0
# 22      TCS  21.0
# 23  Infosys   NaN
# 24      TCS   NaN
# ..      ...   ...
# 95  Infosys   NaN
# 96      TCS   NaN
# 97  Infosys  22.0
# 98      TCS  33.0
# 99      CTS  44.0
#
# [80 rows x 2 columns]

# %%
k = ddff.iloc[20:100,[0,1]]
print(k)
# Out:
#     Company   Age
# 20      TCS  37.0
# 21  Infosys  50.0
# 22      TCS  21.0
# 23  Infosys   NaN
# 24      TCS   NaN
# ..      ...   ...
# 95  Infosys   NaN
# 96      TCS   NaN
# 97  Infosys  22.0
# 98      TCS  33.0
# 99      CTS  44.0
#
# [80 rows x 2 columns]

# %%
# Retrieve 20 to 100 rows and Company and age usig loc
l = ddff.loc[20:100,['Company','Age']]
print(l)
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %%
# Chage the data in 100 row and Place as 'Noida'


x = ddff.loc[100] # (original Data)
print(x)
# Out:
# Company       CTS
# Age          22.0
# Salary        NaN
# Place      Cochin
# Country     India
# Name: 100, dtype: object

# %%
# solution
x = ddff.loc[100,'Place'] = 'Noida'
# To check in data( Cochin to Noida in "Place" column )
y = ddff.loc[100]
print(y)
# Out:
# Company      CTS
# Age         22.0
# Salary       NaN
# Place      Noida
# Country    India
# Name: 100, dtype: object

# %%
# Change the column 'Place' to 'City
ddff.head(0) # Original data
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, Place, Country]
# Index: []

# %%
ddff.rename(columns = {'Place':'City'},inplace = True) # Code to rename "Place" as "City" in column
ddff.head(0)
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, City, Country]
# Index: []

# %%
# List down the unique data in each columns and find length of unique data

uq = ddff.nunique(axis=0) # axis=0 for Rows
print(uq)
# Out:
# Company     6
# Age        29
# Salary     40
# City       11
# Country     1
# dtype: int64

# %%
uq1 = ddff.nunique(axis=1) # axis=1 for Columns
print(uq1)
# Out:
# 0      4
# 1      4
# 2      5
# 3      5
# 4      5
#       ..
# 144    5
# 145    5
# 146    5
# 147    5
# 148    0
# Length: 149, dtype: int64

# %%
# Rename all the possible labels of column in Company as three labels TCS CTS Infosys

# %%
# Where ever you see age as 0 replace with NA

# Hint df[df.Age==20] = np.isnan

# %%
# Check how many duplicated data is there?
print(ddff.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 144     True
# 145     True
# 146     True
# 147     True
# 148    False
# Length: 149, dtype: bool

# %%
# Remove all duplicated rowise data
ddff.drop_duplicates(inplace=True)
print(ddff.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 140    False
# 141    False
# 142    False
# 143    False
# 148    False
# Length: 141, dtype: bool

# %%
# Remove the column 'Country'
ddff.drop('Country',inplace=True,axis=1)
print(ddff)
# Out:
#      Company   Age  Salary     Place
# 0        TCS  20.0     NaN   Chennai
# 1    Infosys  30.0     NaN    Mumbai
# 2        TCS  35.0  2300.0  Calcutta
# 3    Infosys  40.0  3000.0     Delhi
# 4        TCS  23.0  4000.0    Mumbai
# ..       ...   ...     ...       ...
# 144  Infosys  22.0  8787.0  Calcutta
# 145  Infosys  44.0  4034.0     Delhi
# 146      TCS  33.0  5034.0    Mumbai
# 147  Infosys  22.0  8202.0    Cochin
# 148      NaN   NaN     NaN       NaN
#
# [148 rows x 4 columns]

# %%
# Remove the row 137
ddff.drop(137,inplace=True,axis=0)
ddff.tail(15)
# Out:
#                        Company   Age  Salary      Place Country
# 132                        TCS   NaN  7084.0     Cochin   India
# 133                        NaN  22.0  8943.0    Chennai   India
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India
# 135                        CTS  40.0  9284.0   Calcutta   India
# 138                        CTS  44.0  3033.0     Cochin   India
# 139                 Congnizant  22.0  2934.0      Noida   India
# 140                    Infosys  44.0  4034.0  Hyderabad   India
# 141                        TCS  33.0  5034.0   Calcutta   India
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India
# 143                        TCS  33.0  9024.0   Calcutta   India
# 144                    Infosys  22.0  8787.0   Calcutta   India
# 145                    Infosys  44.0  4034.0      Delhi   India
# 146                        TCS  33.0  5034.0     Mumbai   India
# 147                    Infosys  22.0  8202.0     Cochin   India
# ...

# %%
# Find number of each labels in Company

# %%
# Find number of each labels in City

# %%
# Find Number of Null Values in each column
ddff.columns.values.tolist()
# Out:
# ['Company', 'Age', 'Salary', 'Place', 'Country']

# %%
check_for_null = ddff['Company'].isnull().values.any()# Boolean method = Find Number of Null Values in each column
print(check_for_null)
# Out:
# True

# %%
check_for_null=ddff['Company'].isnull()
print(check_for_null)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 144    False
# 145    False
# 146    False
# 147    False
# 148     True
# Name: Company, Length: 147, dtype: bool

# %%
check_for_null_1=ddff['Company'].isnull().sum()
print(check_for_null_1)
# Out:
# 8

# %%
check_for_null_2=ddff['Age'].isnull().sum()
print(check_for_null_2)
# Out:
# 18

# %%
check_for_null_3=ddff['Place'].isnull().sum()
print(check_for_null_3)
# Out:
# 15

# %%
check_for_null_4=ddff['Salary'].isnull().sum()
print(check_for_null_4)
# Out:
# 24

# %%
# Remove all Null values in Salary
#('Country',inplace=True,axis=1)
remove_null_1=ddff.dropna(subset=['Salary'])
print(remove_null_1)
# Out:
#      Company   Age  Salary     Place Country
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# 5    Infosys   NaN  5000.0  Calcutta   India
# 6        TCS   NaN  6000.0   Chennai   India
# ..       ...   ...     ...       ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
#
# [123 rows x 5 columns]

# %%
# Replace the Null values in Comapany with mode
fill_mode = ddff['Company'].mode()[0]
ddff['Company'].fillna(fill_mode,inplace = True)
ddff
# Out:
#                                                Company   Age  Salary  \
# 0                                                  TCS  20.0     NaN
# 1                                              Infosys  30.0     NaN
# 2                                                  TCS  35.0  2300.0
# 3                                              Infosys  40.0  3000.0
# 4                                                  TCS  23.0  4000.0
# ..                                                 ...   ...     ...
# 144                                            Infosys  22.0  8787.0
# 145                                            Infosys  44.0  4034.0
# 146                                                TCS  33.0  5034.0
# 147                                            Infosys  22.0  8202.0
# 148  https://raw.githubusercontent.com/balaji2v/Inc...   NaN     NaN
#
#         Place Country
# 0     Chennai   India
# 1      Mumbai   India
# 2    Calcutta   India
# 3       Delhi   India
# ...

# %%
check_for_null100=ddff['Company'].isnull().sum()
print(check_for_null100)
# Out:
# 0

# %%
# Replace the null value in Salary with median
replace_null_median = ddff['Salary'].median()
ddff['Salary'].fillna(replace_null_median,inplace=True)
ddff
# Out:
#                                                Company   Age  Salary  \
# 0                                                  TCS  20.0  5000.0
# 1                                              Infosys  30.0  5000.0
# 2                                                  TCS  35.0  2300.0
# 3                                              Infosys  40.0  3000.0
# 4                                                  TCS  23.0  4000.0
# ..                                                 ...   ...     ...
# 144                                            Infosys  22.0  8787.0
# 145                                            Infosys  44.0  4034.0
# 146                                                TCS  33.0  5034.0
# 147                                            Infosys  22.0  8202.0
# 148  https://raw.githubusercontent.com/balaji2v/Inc...   NaN  5000.0
#
#         Place Country
# 0     Chennai   India
# 1      Mumbai   India
# 2    Calcutta   India
# 3       Delhi   India
# ...

# %%
# Replace the null value in age with mean
replace_null_mean = ddff['Age'].mean()
ddff['Age'].fillna(replace_null_mean,inplace=True)
ddff
# Out:
#                                                Company       Age  Salary  \
# 0                                                  TCS  20.00000  5000.0
# 1                                              Infosys  30.00000  5000.0
# 2                                                  TCS  35.00000  2300.0
# 3                                              Infosys  40.00000  3000.0
# 4                                                  TCS  23.00000  4000.0
# ..                                                 ...       ...     ...
# 144                                            Infosys  22.00000  8787.0
# 145                                            Infosys  44.00000  4034.0
# 146                                                TCS  33.00000  5034.0
# 147                                            Infosys  22.00000  8202.0
# 148  https://raw.githubusercontent.com/balaji2v/Inc...  30.48062  5000.0
#
#         Place Country
# 0     Chennai   India
# 1      Mumbai   India
# ...

# %%
# Filter the data with age>40 and Salary<5000

# %%
# Draw the pie chart for place and Company

# %%
# Find the mean age with repective to the Company

# %%
# Draw an histogram chart for age, Salary

# %%
# Find the mean, count, median of salary with repective to the place
